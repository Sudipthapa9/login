# %%
#multiplication table of 5 using while loop
'''questions print the prime numbers form 1 to 100 using while loop'''
i =1
while i <=10:
    print("5 x", i, "=", 5*i)
i+=1

# %%
num = 2

while num <= 100:
    i = 2
    is_prime = True

    while i <= num // 2:
        if num % i == 0:
            is_prime = False
            break
        i += 1

    if is_prime:
        print(num)

    num += 1
